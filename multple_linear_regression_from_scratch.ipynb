# %% [markdown]
# #Multiple Linear Regression from scratch using both closed looped solution and gradient descent algorithm

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
sns.get_dataset_names()

# %%
diamond=sns.load_dataset('diamonds')
diamond

# %% [markdown]
# #lets focus on only numerical data dropping categorical ones

# %%
drop_columns=diamond.columns[1:4]
drop_columns

# %%
diamond.drop(columns=drop_columns,inplace=True)

# %%
diamond.head(10)

# %%
diamond.hist(bins=50,figsize=(10,7))

# %%
diamond.info()
